# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime as dt
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import Imputer, RobustScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, log_loss, roc_auc_score
from sklearn.model_selection import GridSearchCV
import lightgbm as lgb

# %% [markdown]
# ### Gather Data

# %%
df = pd.read_csv('Trades - ML Class 520 before G.csv')
df = df.append(pd.read_csv('Trades - ML Class 520 After G.csv'))
df.shape
# Out:
# (33598, 145)

# %%
print(df.entry_time.min(), df.entry_time.max())
# Out:
# 2016-04-01 13:36:05.006700 2018-05-16 15:38:05.006700

# %% [markdown]
# ### Visualize Data ###

# %%
### Define Features to Train Model on ###
features = list(df.loc[:,'entry_collect.Bar_mins_five_ago':'entry_collect.upper_limit_price_minus_last_atr'])
features
# Out:
# ['entry_collect.Bar_mins_five_ago',
#  'entry_collect.Daily_DEMA_Three_Five_Diff',
#  'entry_collect.Daily_DEMA_Three_Ten_Diff',
#  'entry_collect.Daily_DEMA_Three_Twenty_Diff',
#  'entry_collect.Daily_Five_DEMA_from_open',
#  'entry_collect.Daily_Ten_DEMA_from_open',
#  'entry_collect.Daily_Three_DEMA_from_open',
#  'entry_collect.Daily_Twelve_DEMA_from_open',
#  'entry_collect.Daily_Twenty_DEMA_from_open',
#  'entry_collect.Daily_gap_four_to_five',
#  'entry_collect.Daily_gap_prior_to_two',
#  'entry_collect.Daily_gap_three_to_four',
#  'entry_collect.Daily_gap_two_to_three',
#  'entry_collect.Daily_range_five_ago',
#  'entry_collect.Daily_range_four_ago',
#  'entry_collect.Daily_range_one_ago',
#  'entry_collect.Daily_range_three_ago',
#  'entry_collect.Daily_range_two_ago',
#  'entry_collect.LIR',
#  'entry_collect.Location_in_range',
#  'entry_collect.New_High_Count',
#  'entry_collect.New_Low_Count',
#  'entry_collect.Number_of_bars',
#  'entry_collect.Over_bought',
#  'entry_collect.RVOL',
#  'entry_collect.SPY_day_move_vs_ATR',
#  'entry_collect.SPY_gap_in_atr',
#  'entry_collect.Stock_Rvol_vs_SPY_RVOL',
#  'entry_collect.TA_ADX',
#  'entry_collect.TA_BBwidth',
#  'entry_collect.TA_CCI',
#  'entry_collect.TA_CMO',
#  'entry_collect.TA_Corell_OC',
#  'entry_collect.TA_Correl_HL',
#  'entry_collect.TA_DX',
#  'entry_collect.TA_FastD',
#  'entry_collect.TA_FastK',
#  'entry_collect.TA_LinReg_Angle',
#  'entry_collect.TA_LinReg_Slope',
#  'entry_collect.TA_MFI',
#  'entry_collect.TA_RSI',
#  'entry_collect.TA_STDDEV',
#  'entry_collect.TA_SlowD',
#  'entry_collect.TA_SlowK',
#  'entry_collect.TA_TRIX',
#  'entry_collect.TA_lowerBB',
#  'entry_collect.TA_upperBB',
#  'entry_collect.Ticks_Downtick_count',
#  'entry_collect.Ticks_Downtick_volume',
#  'entry_collect.Ticks_Up_vs_Down_Volume',
#  'entry_collect.Ticks_Uptick_Volume',
#  'entry_collect.Ticks_Uptick_count',
#  'entry_collect.Ticks_up_vs_down',
#  'entry_collect.VXX_day_move_vs_ATR',
#  'entry_collect.ask_lift_count',
#  'entry_collect.ask_to_bid',
#  'entry_collect.ask_to_neutral',
#  'entry_collect.atr',
#  'entry_collect.avol',
#  'entry_collect.bar_mins_fifteen_ago',
#  'entry_collect.bar_mins_one_ago',
#  'entry_collect.bar_mins_sixty_ago',
#  'entry_collect.bar_open_vs_close_five',
#  'entry_collect.bar_open_vs_close_four',
#  'entry_collect.bar_open_vs_close_one',
#  'entry_collect.bar_open_vs_close_three',
#  'entry_collect.bar_open_vs_close_two',
#  'entry_collect.bar_range_fifteen',
#  'entry_collect.bar_range_five',
#  'entry_collect.bar_range_one',
#  'entry_collect.bar_range_sixty',
#  'entry_collect.bar_range_thirty',
#  'entry_collect.bid_to_neutral',
#  'entry_collect.change_from_open_in_atr',
#  'entry_collect.count_last_fifteen_bars',
#  'entry_collect.count_last_five_bars',
#  'entry_collect.count_last_sixty_bars',
#  'entry_collect.daily_high_minus_last_atr',
#  'entry_collect.daily_low_minus_last_atr',
#  'entry_collect.daily_spread_in_atr',
#  'entry_collect.day_range_as_ATR',
#  'entry_collect.distance_by_volume_11AM',
#  'entry_collect.fifteebarvwapminusvwapinatr',
#  'entry_collect.fifteen_min_slope_vwap',
#  'entry_collect.fifteenbarvwapminuslastinatr',
#  'entry_collect.five_min_slope_vwap',
#  'entry_collect.fivebarvwapminsvwapinatr',
#  'entry_collect.fivebarvwapminuslastinatr',
#  'entry_collect.fivedayrangevsatr',
#  'entry_collect.fourteenlocinrange',
#  'entry_collect.gap_in_atr',
#  'entry_collect.last_minus_vwap_in_atr',
#  'entry_collect.lower_limit_price_minus_last_atr',
#  'entry_collect.minsAbovePremarketHigh',
#  'entry_collect.minsBelowPremarketHigh',
#  'entry_collect.mins_above_open',
#  'entry_collect.mins_below_open',
#  'entry_collect.net_percent_change',
#  'entry_collect.net_percent_change_open',
#  'entry_collect.premarket_bars',
#  'entry_collect.premarket_range_in_atr',
#  'entry_collect.premarket_volume',
#  'entry_collect.sixty_min_slope_vwap',
#  'entry_collect.sixtybarvwapminuslastinatr',
#  'entry_collect.sixtybarvwapminusvwapinatr',
#  'entry_collect.sixtydaylocinrange',
#  'entry_collect.sliding_gap_percent',
#  'entry_collect.slope_vwap_from_open',
#  'entry_collect.st_raw_s',
#  'entry_collect.st_raw_s_mean',
#  'entry_collect.st_raw_score',
#  'entry_collect.st_raw_volatility',
#  'entry_collect.st_s',
#  'entry_collect.st_s_buzz',
#  'entry_collect.st_s_dispersion',
#  'entry_collect.st_s_mean',
#  'entry_collect.st_s_score',
#  'entry_collect.st_s_volatility',
#  'entry_collect.st_s_volume',
#  'entry_collect.st_sv_mean',
#  'entry_collect.st_sv_score',
#  'entry_collect.st_sv_volaility',
#  'entry_collect.tendaylocinrange',
#  'entry_collect.tendayrangevsatr',
#  'entry_collect.threedaylocinrange',
#  'entry_collect.twentydayrangevsatr',
#  'entry_collect.twohundreddaylocinrange',
#  'entry_collect.upper_limit_price_minus_last_atr']

# %%
# Check type of each feature is float
print('Data Types:')
for i in features:
    t = df[i].dtype
    if t != float:
        print(i, t)
        features.remove(i)
# Out:
# Data Types:

# %%
# Check for null values 
print('Null Columns:')
for i in features:
    c = df[i].isnull().sum() / float(len(df))
    if c > 0.95:
        print(i, c)
        features.remove(i)
# Out:
# Null Columns:
# entry_collect.Location_in_range 1.0

# %%
# Check for zero values
print('Zero Columns:')
for i in features:
    n = (df[i] == 0).astype(int).sum() / float(len(df))
    if n > 0.95:
        print(i, n)
        features.remove(i)
# Out:
# Zero Columns:

# %%
# Check unique values in each feature
print('Unique Values:')
for i in features:
    u = len(df[i].unique()) / float(len(df))
    if u < 0.1:
        print(i, u)
# Out:
# Unique Values:
# entry_collect.New_High_Count 0.013036490267277814
# entry_collect.New_Low_Count 0.013929400559557116
# entry_collect.Number_of_bars 0.0439907137329603
# entry_collect.Over_bought 5.952735281862015e-05
# entry_collect.SPY_day_move_vs_ATR 0.06643252574558009
# entry_collect.SPY_gap_in_atr 0.01583427584975296
# entry_collect.VXX_day_move_vs_ATR 0.06684921721531044
# entry_collect.ask_lift_count 0.005893207929043395
# entry_collect.count_last_five_bars 0.08705875349723198
# entry_collect.mins_above_open 0.01104232394785404
# entry_collect.mins_below_open 0.011012560271444729
# entry_collect.premarket_bars 0.004940770283945473
# entry_collect.st_s_buzz 0.08054050836359307
# entry_collect.st_s_dispersion 0.019733317459372582
# entry_collect.st_s_mean 0.08488600511935235
# entry_collect.st_s_volatility 0.0900946484909816
# entry_collect.st_s_volume 0.021489374367521876

# %% [markdown]
# ### Label Data with Different Classes

# %%
### Define Objective and Label ###
df['maxreturn'] = df.mtm_pl
df.maxreturn.describe()
# Out:
# count    33598.000000
# mean        -0.948192
# std         22.414563
# min       -436.240000
# 25%        -11.480000
# 50%         -1.300000
# 75%          8.820000
# max        550.240000
# Name: maxreturn, dtype: float64

# %%
df['label'] = (df.maxreturn > 10).astype(int)

# %%
### Look at return details ###
print('Percent of Target Trades:', df.label.sum() / float(len(df)))
# Out:
# Percent of Target Trades: 0.229745818203

# %% [markdown]
# ### Split Data into Training and Testing Sets

# %%
### Split the data into training, testing sets ###
train = df[(pd.to_datetime(df.entry_time) < pd.to_datetime('2018-01-01')) & 
           (pd.to_datetime(df.entry_time) >= pd.to_datetime('2014-01-01'))]
test = df[pd.to_datetime(df.entry_time) >= pd.to_datetime('2018-01-01')]

X_train = train.loc[:,features]
y_train = train.loc[:,'label']

X_test = test.loc[:,features]
y_test = test.loc[:,'label']

print('Length of Training Set: ' + str(len(train)))
print('Length of Testing Set: ' + str(len(test)))
# Out:
# Length of Training Set: 25704
# Length of Testing Set: 7894

# %%
X_train.shape
# Out:
# (25704, 127)

# %% [markdown]
# ### Clean and Standardize Data

# %%
### Remove null values and replace with the median of each column ###
transform = Imputer(missing_values='NaN',strategy='median')

### Find median of each column in training set and replace null values ###
X_train = transform.fit_transform(X_train)

### Apply median from training set to null values of test set ###
X_test = transform.transform(X_test)

# %% [markdown]
# ### Train Random Forest

# %%
### Train and fit classifier to Training Data ###
scores = {}

for ne in range(100, 600, 100):
    for md in range(3, 11):
        for mln in range(4, 100, 4):
            clf = RandomForestClassifier(n_estimators=ne, max_depth=md, max_leaf_nodes=mln, n_jobs=-1, verbose=0)

            clf.fit(X_train, y_train)

            y_pred = clf.predict(X_test)
            y_pred.sum()

            metric = roc_auc_score(y_test, y_pred)
# 0.501349293928
# 0.501717363144
# 0.501121399671
# 0.501489468886
# 0.501577188185
# 0.501033680372
# 0.501805082442
# 0.500945961074
# 0.502260870956
# 0.501945257401
# 0.501577188185
# 0.5
# 0.5
# 0.50082385773
# 0.500736138432
# 0.50082385773
# 0.501051751987
# 0.500700874794
# 0.500928769051
# 0.500928769051
# 0.501296838267
# 0.501752626781
# 0.50106894401
# 0.50106894401
# 0.500753330455
# 0.501805082442
# 0.502032976699
# 0.500665611156
# 0.501033680372
# 0.501980521038
# 0.501489468886
# 0.501577188185
# 0.502173151658
# 0.501121399671
# 0.501577188185
# 0.5
# 0.5
# 0.50082385773
# 0.50082385773
# 0.500648419134
# 0.501104207648
# 0.500928769051
# 0.50106894401
# 0.50106894401
# 0.50106894401
# 0.500981224712
# 0.501349293928
# 0.50106894401
# 0.501121399671
# 0.501805082442
# 0.501437013226
# 0.501805082442
# 0.501121399671
# 0.501489468886
# 0.501261574629
# 0.502260870956
# 0.502173151658
# 0.502068240336
# 0.501857538102
# 0.5
# 0.500227894257
# 0.500508244175

# %%
### Feature Importances ###
importances = sorted(list(zip(clf.feature_importances_, new_features)),reverse=True)
# while len(importances) > 50:
importances = importances[:int(len(importances)*0.9)]
new_features = []
for i, f in importances:
    new_features.append(f)

# %%
len(new_features)
# Out:
# 64

# %%
features = new_features

# %%
features
# Out:
# ['entry_collect.bar_range_fifteen',
#  'entry_collect.VXX_day_move_vs_ATR',
#  'entry_collect.day_range_as_ATR',
#  'entry_collect.bar_range_thirty',
#  'entry_collect.bar_range_sixty',
#  'entry_collect.Ticks_Downtick_count',
#  'entry_collect.TA_BBwidth',
#  'entry_collect.bar_range_five',
#  'entry_collect.minsBelowPremarketHigh',
#  'entry_collect.Ticks_Uptick_count',
#  'entry_collect.SPY_gap_in_atr',
#  'entry_collect.mins_below_open',
#  'entry_collect.fivebarvwapminsvwapinatr',
#  'entry_collect.slope_vwap_from_open',
#  'entry_collect.daily_low_minus_last_atr',
#  'entry_collect.Ticks_Uptick_Volume',
#  'entry_collect.fifteebarvwapminusvwapinatr',
#  'entry_collect.last_minus_vwap_in_atr',
#  'entry_collect.change_from_open_in_atr',
#  'entry_collect.mins_above_open',
#  'entry_collect.sixtybarvwapminusvwapinatr',
#  'entry_collect.Ticks_Downtick_volume',
#  'entry_collect.daily_high_minus_last_atr',
#  'entry_collect.RVOL',
#  'entry_collect.SPY_day_move_vs_ATR',
#  'entry_collect.bar_range_one',
#  'entry_collect.minsAbovePremarketHigh',
#  'entry_collect.count_last_sixty_bars',
#  'entry_collect.twohundreddaylocinrange',
#  'entry_collect.New_High_Count',
#  'entry_collect.Daily_gap_prior_to_two',
#  'entry_collect.Daily_range_one_ago',
#  'entry_collect.gap_in_atr',
#  'entry_collect.Number_of_bars',
#  'entry_collect.Daily_gap_four_to_five',
#  'entry_collect.Daily_range_five_ago',
#  'entry_collect.count_last_five_bars',
#  'entry_collect.TA_STDDEV',
#  'entry_collect.Daily_range_two_ago',
#  'entry_collect.Ticks_up_vs_down',
#  'entry_collect.New_Low_Count',
#  'entry_collect.Daily_DEMA_Three_Five_Diff',
#  'entry_collect.lower_limit_price_minus_last_atr',
#  'entry_collect.fifteenbarvwapminuslastinatr',
#  'entry_collect.ask_to_neutral',
#  'entry_collect.count_last_fifteen_bars',
#  'entry_collect.sixty_min_slope_vwap',
#  'entry_collect.Daily_DEMA_Three_Ten_Diff',
#  'entry_collect.threedaylocinrange',
#  'entry_collect.Daily_gap_three_to_four',
#  'entry_collect.Daily_DEMA_Three_Twenty_Diff',
#  'entry_collect.upper_limit_price_minus_last_atr',
#  'entry_collect.twentydayrangevsatr',
#  'entry_collect.bar_open_vs_close_four',
#  'entry_collect.sixtydaylocinrange',
#  'entry_collect.tendaylocinrange',
#  'entry_collect.Daily_range_three_ago',
#  'entry_collect.bid_to_neutral',
#  'entry_collect.daily_spread_in_atr',
#  'entry_collect.tendayrangevsatr',
#  'entry_collect.atr',
#  'entry_collect.fifteen_min_slope_vwap',
#  'entry_collect.Daily_Three_DEMA_from_open',
#  'entry_collect.Daily_Twenty_DEMA_from_open']

# %%
y_pred = clf.predict(X_test)
y_pred.sum()
# Out:
# 12156

# %%
trades = test.assign(pred = y_pred)
trades = trades[trades.pred > 0.5]

# %%
print('Original Max Return - No ML')
print(test.maxreturn.describe())
print('---------------')
print('Max Return with ML')
print(trades.maxreturn.describe())
# Out:
# Original Max Return - No ML
# count    69200.000000
# mean         0.309639
# std          0.297807
# min         -1.654131
# 25%          0.095233
# 50%          0.238095
# 75%          0.444445
# max          7.350002
# Name: maxreturn, dtype: float64
# ---------------
# Max Return with ML
# count    12156.000000
# mean         0.435956
# std          0.372155
# min         -1.654131
# 25%          0.169492
# 50%          0.362379
# 75%          0.627213
# max          3.303519
# Name: maxreturn, dtype: float64

# %%
trades = trades.sort_values('entry_time')
trades['cpl'] = trades.mtm_pl.cumsum()
test = test.sort_values('entry_time')
test['cpl'] = test.mtm_pl.cumsum()
print('Original PnL - No ML')
test.plot(x='entry_time',y='cpl',figsize=[12,8])
plt.show()
print('----------------')
print('PnL with ML')
trades.plot(x='entry_time',y='cpl',figsize=[12,8])
plt.show()
# Out:
# Original PnL - No ML
# ----------------
# PnL with ML

# %%
### Feature Importances ###
importances = sorted(list(zip(clf.feature_importances_, features)),reverse=True)
# while len(importances) > 50:
importances = importances[:int(len(importances)*0.9)]
for i, f in importances:
    print(f, i)
# Out:
# entry_collect.day_range_as_ATR 0.0443045960221
# entry_collect.bar_range_fifteen 0.0416088286834
# entry_collect.bar_range_sixty 0.0414432841239
# entry_collect.VXX_day_move_vs_ATR 0.0391252663588
# entry_collect.bar_range_thirty 0.0345618089665
# entry_collect.Ticks_Downtick_count 0.0257313317958
# entry_collect.bar_range_five 0.0255946330784
# entry_collect.minsBelowPremarketHigh 0.0238952695155
# entry_collect.TA_BBwidth 0.0224171010543
# entry_collect.Ticks_Uptick_count 0.0223256646349
# entry_collect.mins_below_open 0.0194838574712
# entry_collect.slope_vwap_from_open 0.0193783256754
# entry_collect.change_from_open_in_atr 0.0184822731666
# entry_collect.fivebarvwapminsvwapinatr 0.0184798649429
# entry_collect.bar_range_one 0.0166827495633
# entry_collect.SPY_gap_in_atr 0.0166796959894
# entry_collect.last_minus_vwap_in_atr 0.0164792302881
# entry_collect.Ticks_Downtick_volume 0.0158620440139
# entry_collect.fifteebarvwapminusvwapinatr 0.0154475936488
# entry_collect.daily_low_minus_last_atr 0.0153874143683
# entry_collect.daily_high_minus_last_atr 0.014743554536
# entry_collect.Ticks_Uptick_Volume 0.0146991696858
# entry_collect.mins_above_open 0.014405170973
# entry_collect.SPY_day_move_vs_ATR 0.0120402834699
# entry_collect.sixtybarvwapminusvwapinatr 0.010966311443
# entry_collect.RVOL 0.00993982427523
# entry_collect.New_High_Count 0.00965380924903
# entry_collect.Ticks_up_vs_down 0.00818606725939
# entry_collect.count_last_fifteen_bars 0.00794621075761
# entry_collect.Daily_DEMA_Three_Five_Diff 0.00773722194163
# entry_collect.minsAbovePremarketHigh 0.00760469097056
# entry_collect.sixty_min_slope_vwap 0.00745235959716
# entry_collect.Daily_gap_prior_to_two 0.0072386974953
# entry_collect.twohundreddaylocinrange 0.00716150049261
# entry_collect.lower_limit_price_minus_last_atr 0.00696964966163
# entry_collect.TA_STDDEV 0.00685765781177
# entry_collect.tendayrangevsatr 0.00668856337885
# entry_collect.Daily_range_two_ago 0.00655866693439
# entry_collect.upper_limit_price_minus_last_atr 0.0064458798062
# entry_collect.Daily_gap_four_to_five 0.00641132106381
# entry_collect.Number_of_bars 0.00619053810251
# entry_collect.daily_spread_in_atr 0.00617709398171
# entry_collect.count_last_five_bars 0.00595038392573
# entry_collect.count_last_sixty_bars 0.00592294804881
# entry_collect.ask_to_bid 0.00588744827676
# entry_collect.TA_upperBB 0.00561817010102
# entry_collect.New_Low_Count 0.00556917609627
# entry_collect.bid_to_neutral 0.00553524116573
# entry_collect.net_percent_change 0.00547360111834
# entry_collect.gap_in_atr 0.00543363632711
# entry_collect.Daily_range_four_ago 0.00540543454946
# entry_collect.Daily_range_one_ago 0.00537567268584
# entry_collect.sixtybarvwapminuslastinatr 0.00527270169273
# entry_collect.tendaylocinrange 0.00526524799608
# entry_collect.Daily_Three_DEMA_from_open 0.00520522041956
# entry_collect.TA_lowerBB 0.00520205411079
# entry_collect.TA_Correl_HL 0.00519471075879
# entry_collect.Daily_Ten_DEMA_from_open 0.0051130790836
# entry_collect.ask_to_neutral 0.0050525008643
# entry_collect.fivebarvwapminuslastinatr 0.00498057154563
# entry_collect.Daily_range_five_ago 0.00491372366783
# entry_collect.fifteen_min_slope_vwap 0.00488584570139
# entry_collect.premarket_volume 0.00488249185745
# entry_collect.Daily_gap_three_to_four 0.00479138428506
# entry_collect.st_raw_s 0.00475097783273
# entry_collect.Stock_Rvol_vs_SPY_RVOL 0.00472489661036
# entry_collect.Daily_DEMA_Three_Twenty_Diff 0.00468497045178
# entry_collect.LIR 0.00467445354921
# entry_collect.sixtydaylocinrange 0.00466136561569
# entry_collect.ask_lift_count 0.00462873457609
# entry_collect.Daily_Five_DEMA_from_open 0.00449476811184
# entry_collect.threedaylocinrange 0.0044603384217
# entry_collect.Daily_DEMA_Three_Ten_Diff 0.00440395521054
# entry_collect.Daily_gap_two_to_three 0.00435036923227
# entry_collect.bar_open_vs_close_four 0.00432378851221
# entry_collect.fourteenlocinrange 0.00428194972482
# entry_collect.Ticks_Up_vs_Down_Volume 0.00426290944344
# entry_collect.five_min_slope_vwap 0.00407618728363
# entry_collect.Daily_range_three_ago 0.00399089568538
# entry_collect.bar_open_vs_close_three 0.00392489358386
# entry_collect.avol 0.00392213138097
# entry_collect.fifteenbarvwapminuslastinatr 0.00387888915734
# entry_collect.bar_open_vs_close_five 0.00387111152045
# entry_collect.Daily_Twelve_DEMA_from_open 0.00386172523282
# entry_collect.bar_open_vs_close_one 0.00383760497632
# entry_collect.fivedayrangevsatr 0.00383499395621
# entry_collect.twentydayrangevsatr 0.00382532765283
# entry_collect.atr 0.00377835188559
# entry_collect.st_s 0.00374265135248
# entry_collect.Daily_Twenty_DEMA_from_open 0.0035661895019
# entry_collect.net_percent_change_open 0.00340551455914
# entry_collect.bar_open_vs_close_two 0.00336811986841
# entry_collect.st_raw_score 0.00333082608371
# entry_collect.st_sv_score 0.00332446303112
# entry_collect.bar_mins_sixty_ago 0.00325201616856
# entry_collect.TA_CMO 0.0031946380326
# entry_collect.TA_SlowD 0.0031798073598
# entry_collect.bar_mins_one_ago 0.00315937703499
# entry_collect.st_s_mean 0.00314078129997
# entry_collect.sliding_gap_percent 0.00313825842199
# entry_collect.TA_RSI 0.00312952459683
# entry_collect.st_s_volume 0.00311691733612
# entry_collect.TA_FastD 0.00303565167179
# entry_collect.TA_DX 0.00296741488523
# entry_collect.TA_ADX 0.00291414833178
# entry_collect.TA_LinReg_Slope 0.00281851331422
# entry_collect.st_sv_mean 0.0027224106318
# entry_collect.Bar_mins_five_ago 0.00270607196204
# entry_collect.TA_LinReg_Angle 0.00270395251439
# entry_collect.TA_Corell_OC 0.00268273919909
# entry_collect.TA_TRIX 0.00262325060336
# entry_collect.TA_CCI 0.00256946007315
# entry_collect.st_raw_volatility 0.00247755358819
# entry_collect.st_s_score 0.00236300975629
# entry_collect.st_s_buzz 0.00234146667468
# entry_collect.st_raw_s_mean 0.0023118081142
# entry_collect.bar_mins_fifteen_ago 0.0017944480855
# entry_collect.st_sv_volaility 0.0017683228987
# entry_collect.TA_FastK 0.00154237583527
# entry_collect.premarket_range_in_atr 0.00141309493026
# entry_collect.TA_MFI 0.00135752655453
# entry_collect.TA_SlowK 0.0013001992881
# entry_collect.st_s_volatility 0.00125268827346
# entry_collect.st_s_dispersion 0.000972536557614
# entry_collect.distance_by_volume_11AM 0.000866364165626
# entry_collect.Over_bought 0.000508305768688
# entry_collect.premarket_bars 5.56915394319e-05

# %%
len(features)
# Out:
# 127

# %% [markdown]
# ## Gradient Boosted Model

# %%
data = lgb.Dataset(X_train, y_train)
param = {'max_depth':6, 'num_leaves':10, 'learning_rate':0.01, 'num_threads':-1,
         'min_data_in_leaf':100, 'objective':'binary', 'metric':'binary_logloss','verbosity':-1}
bst = lgb.train(param, data, 500)

# %%
y_pred = bst.predict(X_test)
y_pred.sum()
# Out:
# 18057.297662074401
